# %%
from PIL import Image
im = Image.open('./images/test.png')

im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=657x876>

# %% [markdown]
# # Premier test

# %%
from os import walk

tree_file_names = []
for (dirpath, dirnames, filenames) in walk('data'):
    tree_file_names.extend(filenames)
    break

# %%
[f'Arbre : {item}' for item in tree_file_names]
# Out:
# ['Arbre : 42b9cdeef8dd13dc6df5066b58ac6b20-milicia_exelsa.jpg',
#  'Arbre : 28f25bccc85f081e8d06ef0a2c4da740-prunus_africana.jpg',
#  'Arbre : 3d6beb0a333deb68536f2ec7c3f49f9d-milicia_excelsa.jpg',
#  'Arbre : 6a01fe1c34a01914049501bc7d27c766-juniperus_procera.jpg',
#  'Arbre : 96050873a2e018e41d670a77ef1eb57d-pino_halepensis.jpg',
#  'Arbre : e17952f4ce571a6548d8e9270a667066-markhamia_lutea.jpg',
#  'Arbre : 72ef80764e0ee9050808276fb82fbe02-bambusa_vulgaris.jpg']
