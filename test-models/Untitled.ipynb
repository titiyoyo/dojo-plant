# %%
import tensorflow as tf
from tensorflow.keras import models

new_model = tf.saved_model.load('/notebooks/test-models/model')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [7], line 4
#       1 import tensorflow as tf
#       2 from tensorflow.keras import models
# ----> 4 new_model = tf.saved_model.load('/notebooks/test-models/model')
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/saved_model/load.py:782, in load(export_dir, tags, options)
#     780 if isinstance(export_dir, os.PathLike):
#     781   export_dir = os.fspath(export_dir)
# --> 782 result = load_partial(export_dir, None, tags, options)["root"]
#     783 return result
#
# File /usr/local/lib/python3.9/dist-packages/tensorflow/python/saved_model/load.py:887, in load_partial(export_dir, filters, tags, options)
#     882 if tags is not None and not isinstance(tags, set):
#     883   # Supports e.g. tags=SERVING and tags=[SERVING]. Sets aren't considered
# ...
